# %%
from dotenv import load_dotenv
from google import genai
from pypdf import PdfReader
import gradio as gr

# %%
reader = PdfReader("Profile.pdf")
resume = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        resume += text

# %%
with open("summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()
print(resume)
# Out:
# Last Upda ted on 6th J anuary 2026
# C VyshnavPrasanth
# vy shna vpr asan th2k@gmail.c om | 999514 720 7 |
# EDUCATION
# NSS COLLEGE OF ENGINEERING
# B. Tech in Computer Science
# A ug 2018 - A ug 2022 | P alakk ad, Ker ala
# LINKS
# Github://vyshnavprasanth
# LinkedIn://vyshnavprasanth27
# EXPERIENCE
# SOFTWARE ENGINEER
# 08/ 2022 - 05/ 2023 (DEXL OCK ), K ochi,
# Ker ala
# • Develop and maintain oftware solutions
# using Java SpringBoot and Rest APIs
# • Write API documentation using Swagger
# and Postman for seamless integration with
# external systems.
# • Utilize Docker for containerization of
# applications.
# • Build AWS Lambda functions with
# Node.js for Serverless Computing. •
# Hosting back-end service in Aws EC2 and
# front-end in AWS S3.
# SYSTEMS ENGINEER
# 09/ 2023 - Presen t ( TC S), K ochi, Ker ala
# • Served as SME for legacy metering
# applications, handling communication.
# issue resolution and coordination with
# stakeholders.
# • Coordinated cross-functional teams to
# manage and ensure timely and efficient
# deployment.
# •Part of an internal team that developed a
# Gen AI - based prototype for ticket
# clustering using machine learning, aimed
# at reducing reliance on expensive
# third-party applications.
# SKILLS
# Languages:
# • GenAI • Core Java • Python • Javascript
# • HTML • CSS • HandlebarsJS
# Fr ame w ork s/Libr aries:
# • Spring Boot • ExpressJS • ReactJS
# • Bootstrap
# F amiliar:
# • Rest API • JSON • SQL: MYSQL
# • NOSQL: MONGODB •AWS(EC2,S3)
# T ools:
# • Splunk • NMAP • Metasploit •
# BurpSuite • Git • Docker • Jenkins
# PROJECTS
# PERSONAL AI ASSISTANT
# • Personal AI assistant that independently communicates with web-
# site visitors, answers questions, and provides context-aware informa-
# tion about my skills, projects, and experience.
# Technology- GenAI, Python
# NETFLIX CLONE
# • Developed a responsive front-end clone for the application Netflix. •
# Technology- ReactJS
# ORDER TRACKER
# • Application where users can track their order status.
# • Technology- ReactJS, Spring Boot, MySQL, Nginx, Docker
# HOSTEL MESS MANAGEMENT APPLICATION
# • Resposible for integrating payment gateway (Razorpay) and other
# modules of the application
# • Technology- Handlebars.js, NodeJS, HTML, CSS, JavaScript
# OTHER PROJECTS
# • Reeboot Kerala Hackathon - Application that alerts food inspectors
# stationed at Sabarimala Temple regarding the hygienic conditions of
# various food stalls, thus ensuring safe food is distributed (HTML, CSS,
# JavaScript)
# • Ecommerce - Application where users can purchase various mobile
# phones(Handlebars.js, NodeJS, HTML, CSS, JavaScript, JQuery.
# • Tournament Management App - Responsible for Backend APIs of (
# Player Profile, Referal Page, User Profile, User Interfaces, Matches Re-
# lated API’s) of a TournamentManagement Application(SringBoot, Reac-
# tJS, AWS EC2, Docker)
# ACHIEVEMENTS
# CERTIFIED PENETRATION TESTER
# | RED TEAM HACKER AC ADEMY
# Sep 2024 – April 2025
# FUNDED FINAL YEAR PROJECT: INTRUSION DETECTION IN
# HOME IOT
# 2021 - 22 | P alakk ad, Ker ala
# Successfully secured funding from the Center for Engineering Research and
# Development (CERD) under APJAKTU for the final year project on Intrusion
# Detection in Home IoT.
# REEBOOT KERALA HACKATHON 2020
# | Department of Higher Education, Gove rnment of Kerala, and
# orchestrated by A S AP
# Mar 2020 | Cherthala, Ker ala
# Our team got shortlisted and selected for Reboot Kerala hackathon 2020 by the
# Department of Higher Education, Government of Kerala, and orchestrated by ASAP.
# held at Cherthala and our team got selected in final 15 on the category Food.
# JOY OF COMPUTING USING PYTHON
# | NP TEL Online Certification
# Sep 2020 – Dec 2020
# Elite + Silver certificate.

# %%
name = "Vyshnav Prasanth"

system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and resume pdf which you can use to answer questions. \
Resume consist of Education section, Links, Experience, Skills, Projects, Achievements \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
Don't assume any facts or information. \
Please ensure you dont mention anyinfo like it was mentioned in summary instead just respond as if {name} is responding\
If you don't know the answer, say so." 
system_prompt += f"\n\n## Summary:\n{summary}\n\n## Resume:\n{resume}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
import os
load_dotenv(override=True)
api_key=os.getenv("GEMINI_API_KEY")
client=genai.Client(api_key=api_key)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
def chat(message, history):
    """
    message: str
    history: list of (user, assistant) tuples from Gradio
    """

    if history is None:
        history = []

    # Prepare Gemini contents
    contents = []

    # System instruction (first message)
    contents.append({
        "role": "user",
        "parts": [{"text": system_prompt}]
    })

    #only past 'max_turn' conversation need to be sent to the model every time
    max_turn=4
    # Add previous conversation only if it exists
    for entry in history[-max_turn:]:
        if len(entry) == 2:
            user_msg, bot_msg = entry
            contents.append({"role": "user", "parts": [{"text": user_msg}]})
            contents.append({"role": "model", "parts": [{"text": bot_msg}]})

    # Add current user message
    contents.append({"role": "user", "parts": [{"text": message}]})

    # Generate response
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=contents,
    )

    return response.text

# %%
#launch user interface for the model
demo=gr.ChatInterface(fn=chat)
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
